# %%
from utils import Timer
from PyCuAttention.kernels.loader import naive_attn
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
Q = torch.randn(32,8,10,64, device = device)
K = torch.randn(32,8,10,64, device = device)
V = torch.randn(32,8,10,64, device = device)

# %%
timer = Timer(
    fn = lambda: naive_attn(q = Q, k = K, v = V, scaling = 0.125),
    warmup_iters=25,
    timed_iters=100
)

# %%
timing_stats = timer.benchmark_time()

# %%
print(timing_stats)
# Out:
# TimingStats | median: 0.14592000097036362 ms | mean: 0.14260288089513778 ms | std_ms: 0.008561262855608633 ms |  cv: 6.003569354187247% | min: 0.130048006772995 ms | max: 0.17510400712490082 ms
